# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.PassengerId.shape
# Out:
# (891,)

# %%
df.Survived.shape
# Out:
# (891,)

# %%
df.Pclass.shape
# Out:
# (891,)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# ...
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Length: 891, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
df.Name.value_counts()
# Out:
# Graham, Mr. George Edward                              1
# Elias, Mr. Tannous                                     1
# Madill, Miss. Georgette Alexandra                      1
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Beane, Mrs. Edward (Ethel Clarke)                      1
# Roebling, Mr. Washington Augustus II                   1
# Moran, Mr. James                                       1
# Padro y Manent, Mr. Julian                             1
# Scanlan, Mr. James                                     1
# Ali, Mr. William                                       1
# Weisz, Mrs. Leopold (Mathilde Francoise Pede)          1
# Abbing, Mr. Anthony                                    1
# Lahtinen, Mrs. William (Anna Sylfven)                  1
# Frost, Mr. Anthony Wood "Archie"                       1
# Lang, Mr. Fang                                         1
# ...
# McEvoy, Mr. Michael                                  1
# ...

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %%
df.Age.value_counts()
# Out:
# 24    30
# 22    27
# 18    26
# 28    25
# 30    25
# 19    25
# 21    24
# 25    23
# 36    22
# 29    20
# 32    18
# 35    18
# 27    18
# 26    18
# 16    17
# ...
# 53.00    1
# 70.50    1
# 14.50    1
# 0.92     1
# 74.00    1
# 36.50    1
# 80.00    1
# 12.00    1
# 55.50    1
# 34.50    1
# 24.50    1
# 66.00    1
# 23.50    1
# 0.67     1
# 20.50    1
# Length: 88, dtype: int64

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# dtype: int64

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# dtype: int64

# %%
df.Fare.value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
# 10.5000    24
# 7.9250     18
# 7.7750     16
# 7.2292     15
# 26.5500    15
# 0.0000     15
# 7.2500     13
# 7.8542     13
# 8.6625     13
# 7.2250     12
# ...
# 15.0000    1
# 28.7125    1
# 61.1750    1
# 6.2375     1
# 15.1000    1
# 39.4000    1
# 81.8583    1
# 61.9792    1
# 7.8000     1
# 22.0250    1
# 47.1000    1
# 13.4167    1
# 14.1083    1
# 15.5500    1
# 13.7917    1
# Length: 248, dtype: int64

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343        7
# 347082          7
# 1601            7
# 347088          6
# CA 2144         6
# 3101295         6
# 382652          5
# S.O.C. 14879    5
# PC 17757        4
# 4133            4
# LINE            4
# 349909          4
# 347077          4
# W./C. 6608      4
# 113760          4
# ...
# STON/O 2. 3101273    1
# 345777               1
# STON/O 2. 3101274    1
# STON/O 2. 3101275    1
# 113794               1
# 2649                 1
# 374887               1
# 349213               1
# 349210               1
# 349242               1
# 349216               1
# 112052               1
# 315088               1
# 349215               1
# W./C. 14258          1
# Length: 681, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %%
df.PassengerId.value_counts().plot(kind='bar')

# %%
df.Survived.value_counts().plot(kind='bar')

# %%
df.Sex.value_counts().plot(kind='bar')

# %%
df.Pclass.value_counts().plot(kind='bar')

# %%
df.Age.value_counts().plot(kind='bar')

# %%
df.Parch.value_counts().plot(kind='bar')

# %%
df.Fare.value_counts().plot(kind='bar')

# %%
df.Ticket.value_counts().plot(kind='bar')

# %%
df.SibSp.value_counts().plot(kind='bar')

# %%
df.Cabin.value_counts().plot(kind='bar')

# %%
df.Embarked.value_counts().plot(kind='bar')

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# ...
# E50    1
# A14    1
# C91    1
# A16    1
# B38    1
# B39    1
# C95    1
# B78    1
# B79    1
# C99    1
# B37    1
# A19    1
# E12    1
# A7     1
# D15    1
# Length: 147, dtype: int64

# %%
df[df.PassengerId==821]
# Out:
#      PassengerId  Survived  Pclass  \
# 820          821         1       1
#
#                                                   Name     Sex  Age  SibSp  \
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female   52      1
#
#      Parch Ticket  Fare Cabin Embarked
# 820      1  12749  93.5   B69        S

# %%
df[df.PassengerId==21]
# Out:
#     PassengerId  Survived  Pclass                  Name   Sex  Age  SibSp  \
# 20           21         0       2  Fynney, Mr. Joseph J  male   35      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 20      0  239865    26   NaN        S

# %%
df[df.Survived==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
df[df.Survived==0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 24            25         0       3
# 26            27         0       3
# 27            28         0       1
# 29            30         0       3
# 30            31         0       1
# 33            34         0       2
# 34            35         0       1
# 35            36         0       1
# 37            38         0       3
# 38            39         0       3
# 40            41         0       3
# 41            42         0       2
# 42            43         0       3
# 45            46         0       3
# ...

# %%
df[df.Pclass==2]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# 33            34         0       2
# 41            42         0       2
# 43            44         1       2
# 53            54         1       2
# 56            57         1       2
# 58            59         1       2
# 66            67         1       2
# 70            71         0       2
# 72            73         0       2
# 78            79         1       2
# 84            85         1       2
# 98            99         1       2
# 99           100         0       2
# 117          118         0       2
# 120          121         0       2
# 122          123         0       2
# 123          124         1       2
# 133          134         1       2
# 134          135         0       2
# 135          136         0       2
# ...

# %%
df[df.Pclass==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# 27            28         0       1
# 30            31         0       1
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 52            53         1       1
# 54            55         0       1
# 55            56         1       1
# 61            62         1       1
# 62            63         0       1
# 64            65         0       1
# 83            84         0       1
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 124          125         0       1
# ...

# %%
df[df.Sex=='male']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %%
df[df.Sex=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
df[df.Age==62]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 252          253         0       1                  Stead, Mr. William Thomas
# 555          556         0       1                         Wright, Mr. George
# 570          571         1       2                         Harris, Mr. George
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch       Ticket   Fare Cabin Embarked
# 252    male   62      0      0       113514  26.55   C87        S
# 555    male   62      0      0       113807  26.55   NaN        S
# 570    male   62      0      0  S.W./PP 752  10.50   NaN        S
# 829  female   62      0      0       113572  80.00   B28      NaN

# %%
df[df.Age==15]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 22            23         1       3              McGowan, Miss. Anna "Annie"
# 352          353         0       3                       Elias, Mr. Tannous
# 689          690         1       1        Madill, Miss. Georgette Alexandra
# 830          831         1       3  Yasbeck, Mrs. Antoni (Selini Alexander)
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
#         Sex  Age  SibSp  Parch  Ticket      Fare Cabin Embarked
# 22   female   15      0      0  330923    8.0292   NaN        Q
# 352    male   15      1      1    2695    7.2292   NaN        C
# 689  female   15      0      1   24160  211.3375    B5        S
# 830  female   15      1      0    2659   14.4542   NaN        C
# 875  female   15      0      0    2667    7.2250   NaN        C

# %%
df[df.Age==27]
# Out:
#      PassengerId  Survived  Pclass  \
# 8              9         1       3
# 41            42         0       2
# 146          147         1       3
# 216          217         1       3
# 221          222         0       2
# 321          322         0       3
# 377          378         0       1
# 551          552         0       2
# 607          608         1       1
# 620          621         0       3
# 681          682         1       1
# 717          718         1       2
# 724          725         1       1
# 804          805         1       3
# 821          822         1       3
# 823          824         1       3
# 866          867         1       2
# 886          887         0       2
#
#                                                   Name     Sex  Age  SibSp  \
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female   27      1
# ...

# %%
df[df.SibSp==0]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 8              9         1       3
# 11            12         1       1
# 12            13         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# 36            37         1       3
# 37            38         0       3
# 42            43         0       3
# 44            45         1       3
# ...

# %%
df[df.SibSp==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 9             10         1       2
# 10            11         1       3
# 13            14         0       3
# 18            19         0       3
# 25            26         1       3
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 46            47         0       3
# 49            50         0       3
# 52            53         1       1
# 53            54         1       2
# 58            59         1       2
# 62            63         0       1
# 65            66         1       3
# 73            74         0       3
# 86            87         0       3
# 92            93         0       1
# ...

# %%
df[df.Parch==3]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 86            87         0       3                   Ford, Mr. William Neal
# 437          438         1       2    Richards, Mrs. Sidney (Emily Hocking)
# 736          737         0       3  Ford, Mrs. Edward (Margaret Ann Watson)
# 774          775         1       2    Hocking, Mrs. Elizabeth (Eliza Needs)
# 858          859         1       3    Baclini, Mrs. Solomon (Latifa Qurban)
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 86     male   16      1      3  W./C. 6608  34.3750   NaN        S
# 437  female   24      2      3       29106  18.7500   NaN        S
# 736  female   48      1      3  W./C. 6608  34.3750   NaN        S
# 774  female   54      1      3       29105  23.0000   NaN        S
# 858  female   24      0      3        2666  19.2583   NaN        C

# %%
df[df.Parch==5]
# Out:
#      PassengerId  Survived  Pclass  \
# 13            14         0       3
# 25            26         1       3
# 610          611         0       3
# 638          639         0       3
# 885          886         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 13                         Andersson, Mr. Anders Johan    male   39      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female   38      1
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  female   39      1
# 638             Panula, Mrs. Juha (Maria Emilia Ojala)  female   41      0
# 885               Rice, Mrs. William (Margaret Norton)  female   39      0
#
#      Parch   Ticket     Fare Cabin Embarked
# 13       5   347082  31.2750   NaN        S
# 25       5   347077  31.3875   NaN        S
# 610      5   347082  31.2750   NaN        S
# 638      5  3101295  39.6875   NaN        S
# 885      5   382652  29.1250   NaN        Q

# %%
df[df.Ticket==347077]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Ticket==347082]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare==31.2750]
# Out:
#      PassengerId  Survived  Pclass  \
# 13            14         0       3
# 119          120         0       3
# 541          542         0       3
# 542          543         0       3
# 610          611         0       3
# 813          814         0       3
# 850          851         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 13                         Andersson, Mr. Anders Johan    male   39      1
# 119                  Andersson, Miss. Ellis Anna Maria  female    2      4
# 541               Andersson, Miss. Ingeborg Constanzia  female    9      4
# 542                  Andersson, Miss. Sigrid Elisabeth  female   11      4
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  female   39      1
# 813                 Andersson, Miss. Ebba Iris Alfrida  female    6      4
# 850            Andersson, Master. Sigvard Harald Elias    male    4      4
#
#      Parch  Ticket    Fare Cabin Embarked
# ...

# %%
df[df.Fare==39.6875]
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 50            51         0       3              Panula, Master. Juha Niilo
# 164          165         0       3            Panula, Master. Eino Viljami
# 266          267         0       3               Panula, Mr. Ernesti Arvid
# 638          639         0       3  Panula, Mrs. Juha (Maria Emilia Ojala)
# 686          687         0       3                Panula, Mr. Jaako Arnold
# 824          825         0       3            Panula, Master. Urho Abraham
#
#         Sex  Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 50     male    7      4      1  3101295  39.6875   NaN        S
# 164    male    1      4      1  3101295  39.6875   NaN        S
# 266    male   16      4      1  3101295  39.6875   NaN        S
# 638  female   41      0      5  3101295  39.6875   NaN        S
# 686    male   14      4      1  3101295  39.6875   NaN        S
# ...

# %%
df[df.Cabin=='NaN']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Embarked=='S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 29            30         0       3
# 33            34         0       2
# 35            36         0       1
# 37            38         0       3
# ...

# %%
df[df.Embarked=='Q']
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 16            17         0       3
# 22            23         1       3
# 28            29         1       3
# 32            33         1       3
# 44            45         1       3
# 46            47         0       3
# 47            48         1       3
# 82            83         1       3
# 109          110         1       3
# 116          117         0       3
# 126          127         0       3
# 143          144         0       3
# 156          157         1       3
# 171          172         0       3
# 186          187         1       3
# 188          189         0       3
# 196          197         0       3
# 198          199         1       3
# 208          209         1       3
# 214          215         0       3
# 241          242         1       3
# 245          246         0       1
# 260          261         0       3
# 264          265         0       3
# ...

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Name.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female   38      0      0  113572    80   B28      NaN
# 829  female   62      0      0  113572    80   B28      NaN

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.PassengerId.hist()

# %%
df.Survived.hist()

# %%
df.Pclass.hist()

# %%
df.Age.hist()

# %%
df.SibSp.hist()

# %%
df.Parch.hist()

# %%
df.Fare.hist()

# %%
df[df.PassengerId==2].Survived.value_counts().plot(kind='barh')

# %%
df[df.PassengerId==1].Survived.value_counts().plot(kind='barh')

# %%
df[df.Pclass==1].Sex.value_counts().plot(kind='barh')

# %%
df[df.Sex=='female'].Age.value_counts().plot(kind='barh')

# %%
df[df.Sex=='female'].Survived.value_counts().plot(kind='barh')

# %%
fig, axs=plt.subplots(1,2)
df[df.Sex=='male'].Survived.value_counts().plot(kind='barh',ax=axs[0],title='male survived')
df[df.Sex=='female'].Survived.value_counts().plot(kind='barh',ax=axs[1],title='female survived')

# %%
fig, axs=plt.subplots(1,2)
df[df.Age==28].Survived.value_counts().plot(kind='barh',ax=axs[0],title='Age28')
df[df.Age==32].Survived.value_counts().plot(kind='barh',ax=axs[1],title='Age32')

# %%
df[df.PassengerId<20].Survived.value_counts().plot(kind='barh')

# %%
df[df.Survived<2].Survived.value_counts().plot(kind='barh')

# %%
df[df.Pclass<2].Survived.value_counts().plot(kind='barh')

# %%
df[df.Age<28].Survived.value_counts().plot(kind='barh')

# %%
df[df.Fare<30].Survived.value_counts().plot(kind='barh')

# %%
df[(df.PassengerId<3) & (df.Sex=='male')].Survived.value_counts().plot(kind='barh')

# %%
df[(df.Age<20) & (df.Sex=='male')].Survived.value_counts().plot(kind='barh')

# %%
df[(df.Fare<30) & (df.Sex=='female')].Survived.value_counts().plot(kind='barh')
